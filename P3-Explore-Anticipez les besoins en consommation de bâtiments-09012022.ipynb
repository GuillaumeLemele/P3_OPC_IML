# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Optimisation-de-l'environnement" data-toc-modified-id="Optimisation-de-l'environnement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Optimisation de l'environnement</a></span></li><li><span><a href="#Définitions-des-fonctions" data-toc-modified-id="Définitions-des-fonctions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Définitions des fonctions</a></span></li><li><span><a href="#Ouverture-du-Dataframe-et-visualisation-des-valeurs-manquantes" data-toc-modified-id="Ouverture-du-Dataframe-et-visualisation-des-valeurs-manquantes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Ouverture du Dataframe et visualisation des valeurs manquantes</a></span></li><li><span><a href="#1er-Nettoyage-:-Suppression-des-lignes-inutiles" data-toc-modified-id="1er-Nettoyage-:-Suppression-des-lignes-inutiles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>1er Nettoyage : Suppression des lignes inutiles</a></span><ul class="toc-item"><li><span><a href="#Bâtiments-résidentiels" data-toc-modified-id="Bâtiments-résidentiels-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Bâtiments résidentiels</a></span></li><li><span><a href="#Dédoublonnage-sur-ID" data-toc-modified-id="Dédoublonnage-sur-ID-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Dédoublonnage sur ID</a></span></li><li><span><a href="#Suppression-lignes-incomplètes" data-toc-modified-id="Suppression-lignes-incomplètes-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Suppression lignes incomplètes</a></span></li></ul></li><li><span><a href="#2ème-nettoyage-:-vérification-&amp;-traitement-des-valeurs-aberrantes" data-toc-modified-id="2ème-nettoyage-:-vérification-&amp;-traitement-des-valeurs-aberrantes-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>2ème nettoyage : vérification &amp; traitement des valeurs aberrantes</a></span><ul class="toc-item"><li><span><a href="#ENERGYSTARScore" data-toc-modified-id="ENERGYSTARScore-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ENERGYSTARScore</a></span></li><li><span><a href="#DataYear" data-toc-modified-id="DataYear-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>DataYear</a></span></li><li><span><a href="#Localisation-et-attributs" data-toc-modified-id="Localisation-et-attributs-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Localisation et attributs</a></span></li></ul></li><li><span><a href="#3ème-Nettoyage-:-Suppression-des-colonnes-inutiles" data-toc-modified-id="3ème-Nettoyage-:-Suppression-des-colonnes-inutiles-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>3ème Nettoyage : Suppression des colonnes inutiles</a></span><ul class="toc-item"><li><span><a href="#Suppression-des-colonnes-ayant-la-quasi-totalité-de-leurs-données-manquantes-:-Comments-&amp;-Outlier" data-toc-modified-id="Suppression-des-colonnes-ayant-la-quasi-totalité-de-leurs-données-manquantes-:-Comments-&amp;-Outlier-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Suppression des colonnes ayant la quasi totalité de leurs données manquantes : Comments &amp; Outlier</a></span></li><li><span><a href="#Suppression-des-colonnes-redondantes-:-WN" data-toc-modified-id="Suppression-des-colonnes-redondantes-:-WN-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Suppression des colonnes redondantes : WN</a></span></li></ul></li><li><span><a href="#Complétion-des-variables-utiles" data-toc-modified-id="Complétion-des-variables-utiles-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Complétion des variables utiles</a></span><ul class="toc-item"><li><span><a href="#Energy-Star-Score" data-toc-modified-id="Energy-Star-Score-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Energy Star Score</a></span></li></ul></li><li><span><a href="#Modification/optimisation-des-variables-utiles" data-toc-modified-id="Modification/optimisation-des-variables-utiles-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Modification/optimisation des variables utiles</a></span><ul class="toc-item"><li><span><a href="#YearsENERGYSTARCertified" data-toc-modified-id="YearsENERGYSTARCertified-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>YearsENERGYSTARCertified</a></span></li></ul></li><li><span><a href="#Analyse-univariée" data-toc-modified-id="Analyse-univariée-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Analyse univariée</a></span><ul class="toc-item"><li><span><a href="#OSEBuildingID" data-toc-modified-id="OSEBuildingID-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>OSEBuildingID</a></span></li><li><span><a href="#DataYear" data-toc-modified-id="DataYear-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>DataYear</a></span></li><li><span><a href="#BuildingType" data-toc-modified-id="BuildingType-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>BuildingType</a></span></li><li><span><a href="#PrimaryPropertyType" data-toc-modified-id="PrimaryPropertyType-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>PrimaryPropertyType</a></span></li><li><span><a href="#YearBuilt" data-toc-modified-id="YearBuilt-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>YearBuilt</a></span></li><li><span><a href="#Nombres-de-bâtiments" data-toc-modified-id="Nombres-de-bâtiments-10.6"><span class="toc-item-num">10.6&nbsp;&nbsp;</span>Nombres de bâtiments</a></span></li><li><span><a href="#Nombres-d'étages" data-toc-modified-id="Nombres-d'étages-10.7"><span class="toc-item-num">10.7&nbsp;&nbsp;</span>Nombres d'étages</a></span></li></ul></li><li><span><a href="#Analyse-multivariée" data-toc-modified-id="Analyse-multivariée-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Analyse multivariée</a></span><ul class="toc-item"><li><span><a href="#Heatmap-des-corrélations-(Pearson)" data-toc-modified-id="Heatmap-des-corrélations-(Pearson)-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Heatmap des corrélations (Pearson)</a></span></li><li><span><a href="#Tableau-des-corrélations-(Pearson)" data-toc-modified-id="Tableau-des-corrélations-(Pearson)-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Tableau des corrélations (Pearson)</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction
# Des relevés minutieux ont été effectués par les agents de la ville en 2016. Voici les données et leur source. Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, vous voulez tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments non destinés à l’habitation pour lesquels elles n’ont pas encore été mesurées.
# Livrable :
# Un notebook de l'analyse exploratoire mis au propre et annoté.

# %% [markdown]
# # Optimisation de l'environnement

# %%
import numpy as np

# %%
import pandas as pd

# %%
import missingno as msno

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # Définitions des fonctions

# %%
# Renvoie les principaux indicateurs pour une analyse univarié ; var. qualitative nominale. 

def ana_uni_nom(df, col):
    description = df[[col]].describe()
    count = description.loc['count'][0]
    nan = df[[col]].isna().sum()
    unique = description.loc['unique'][0]
    top = description.loc['top'][0]
    freq = description.loc['freq'][0]

    print(f"Il y a {count} entrées.")  
    print(f"Il y a {nan[0]} valeurs manquantes")
    print(f"Il y a {unique} valeurs uniques.")
    print(f"Le mode est de {freq}.")
    print(f"La valeur du mode correspond à {top}.")

# %%
# Renvoie les principaux indicateurs de position centrales et de dispersion pour une analyse univarié ; var. qtv.

def ana_uni_qtv_er(df, col):
    description = df[[col]].describe()
    count = description.loc['count'][0]
    nan = df[[col]].isna().sum()
    min_value = description.loc['min'][0]
    max_value = description.loc['max'][0]
    mean = description.loc['mean'][0]
    median = description.loc['50%'][0]
    q1 = description.loc['25%'][0]
    q3 = description.loc['75%'][0]
    iqr = q3 - q1
    std = description.loc['std'][0]

    print(f"Il y a {count} entrées.")  
    print(f"Il y a {nan[0]} valeurs manquantes")
    print(f"La valeur min. est de {min_value:.2f}.")
    print(f"La valeur max. est de {max_value:.2f}.")
    print(f"La moyenne est de {mean:.2f}.")
    print(f"L'étendue est de {max_value - min_value:.2f}.")
    print(f"Le premier quartile se situe à {q1:.2f}.")
    print(f"La médiane se situe à {median:.2f}.")
    print(f"Le troisième quartile se situe à {q3:.2f}.")
    print(f"L'écart interquartile est de {iqr:.2f}.")
    print(f"L'écart type est de {std:.2f}.")

# %%
# Représentations graphiques barplot

def plot_bins_distribution(data, x, bins, title, xlabel, ylabel):
  fig = plt.figure(figsize=(7,7))
  ax = sns.histplot(data=data, x=x, bins=bins)
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)
  plt.title(title)
  plt.show()

# %% [markdown]
# # Ouverture du Dataframe et visualisation des valeurs manquantes

# %%
# Ouverture du dataframe. Pd.set_option pour afficher toutes les colonnes

B_E_B = pd.read_csv("2016_Building_Energy_Benchmarking.csv")
pd.set_option('display.max_columns', None)
B_E_B.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# ...

# %%
# Il y a 46 colonnes, variables caractérisants nos bâtiments, et 3376 bâtiments en totol. 

B_E_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
# ...

# %%
B_E_B.describe()
# Out:
#        OSEBuildingID  DataYear       ZipCode  CouncilDistrictCode  \
# count    3376.000000    3376.0   3360.000000          3376.000000
# mean    21208.991114    2016.0  98116.949107             4.439277
# std     12223.757015       0.0     18.615205             2.120625
# min         1.000000    2016.0  98006.000000             1.000000
# 25%     19990.750000    2016.0  98105.000000             3.000000
# 50%     23112.000000    2016.0  98115.000000             4.000000
# 75%     25994.250000    2016.0  98122.000000             7.000000
# max     50226.000000    2016.0  98272.000000             7.000000
#
#           Latitude    Longitude    YearBuilt  NumberofBuildings  \
# count  3376.000000  3376.000000  3376.000000        3368.000000
# mean     47.624033  -122.334795  1968.573164           1.106888
# std       0.047758     0.027203    33.088156           2.108402
# min      47.499170  -122.414250  1900.000000           0.000000
# ...

# %%
# Les variables sont en majoritées complètes sauf quelques unes. 
msno.bar(B_E_B.sample(1000))
# Out:
# <AxesSubplot:>

# %%
# Répartition homogène des valeurs au sein de nos variables
msno.matrix(B_E_B.sample(250))
# Out:
# <AxesSubplot:>

# %%
# Nous précisons les valeurs manquantes pour chaque colonne.  
# 8 colonnes ont une majorité de valeurs manquantes. Il faut donc étudier chaque variable séparement pour trouver la solution adéquate. 
# 16 colonnes ont une dizaine de valeurs manquante, soit moins de 1% sur la totalité des données de la colonne. Il est surement possibile de supprimer ces lignes manquantes sans dommage réel sur notre df. 
# Le reste n'a pas de valeurs manquantes.

B_E_B.isna().sum()
# Out:
# OSEBuildingID                         0
# DataYear                              0
# BuildingType                          0
# PrimaryPropertyType                   0
# PropertyName                          0
# Address                               0
# City                                  0
# State                                 0
# ZipCode                              16
# TaxParcelIdentificationNumber         0
# CouncilDistrictCode                   0
# Neighborhood                          0
# Latitude                              0
# Longitude                             0
# YearBuilt                             0
# NumberofBuildings                     8
# NumberofFloors                        0
# PropertyGFATotal                      0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# ListOfAllPropertyUseTypes             9
# LargestPropertyUseType               20
# LargestPropertyUseTypeGFA            20
# ...

# %% [markdown]
# # 1er Nettoyage : Suppression des lignes inutiles
# vous voulez tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments non destinés à l’habitation pour lesquels elles n’ont pas encore été mesurées.

# %% [markdown]
# ## Bâtiments résidentiels

# %%
B_E_B['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %%
B_E_B.shape
# Out:
# (3376, 46)

# %%
B_E_B = B_E_B[B_E_B['BuildingType'].str.contains('Multifamily') == False]

# %%
B_E_B['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
# Notre dataframe passe de 3776 lignes à 1668.
B_E_B.shape
# Out:
# (1668, 46)

# %% [markdown]
# ## Dédoublonnage sur ID
# La colonne OSEBuildingID est la variable d'identification de nos individus.
# Nous procédons donc à une vérification de potentiels doublons.
# Il n'y a pas de doublons

# %%
# By setting keep on False, all duplicates are True.
B_E_B['OSEBuildingID'].duplicated(keep = False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3371    False
# 3372    False
# 3373    False
# 3374    False
# 3375    False
# Name: OSEBuildingID, Length: 1668, dtype: bool

# %%
B_E_B.duplicated(['OSEBuildingID'], keep = False).sum()
# Out:
# 0

# %% [markdown]
# ## Suppression lignes incomplètes
# 16 colonnes ont une dizaine de valeurs manquante, soit moins de 1% sur la totalité des données de la colonne. Il est surement possibile de supprimer ces lignes manquantes sans dommage réel sur l'exploration de notre df et l'application de nos modèles de ML.

# %%
B_E_B.shape
# Out:
# (1668, 46)

# %%
# supprimer uniquement les lignes qui ont DES VALEURS MANQUANTES DANS TOUTES LES COLONNES
B_E_B = B_E_B.dropna(how='all')

# %%
# Aucune ligne a des valeurs manquantes dans toutes ses colonnes 
B_E_B.shape
# Out:
# (1668, 46)

# %%
B_E_B = B_E_B.dropna(subset=['ZipCode','LargestPropertyUseType','LargestPropertyUseTypeGFA','SiteEUI(kBtu/sf)','SiteEUIWN(kBtu/sf)','SourceEUI(kBtu/sf)','SourceEUIWN(kBtu/sf)','SiteEnergyUse(kBtu)','NaturalGas(therms)','NaturalGas(kBtu)','TotalGHGEmissions','GHGEmissionsIntensity'])
B_E_B.shape
# Out:
# (1644, 46)

# %%
# Nous avons procéder au nettoyages des données manquantes sur les colonnes ayant moins de 1% de valeurs imcomplètes.
B_E_B.isna().sum()
# Out:
# OSEBuildingID                         0
# DataYear                              0
# BuildingType                          0
# PrimaryPropertyType                   0
# PropertyName                          0
# Address                               0
# City                                  0
# State                                 0
# ZipCode                               0
# TaxParcelIdentificationNumber         0
# CouncilDistrictCode                   0
# Neighborhood                          0
# Latitude                              0
# Longitude                             0
# YearBuilt                             0
# NumberofBuildings                     0
# NumberofFloors                        0
# PropertyGFATotal                      0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# ListOfAllPropertyUseTypes             0
# LargestPropertyUseType                0
# LargestPropertyUseTypeGFA             0
# ...

# %%
# Répartition homogène des valeurs au sein de nos variables
msno.matrix(B_E_B.sample(250))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2ème nettoyage : vérification & traitement des valeurs aberrantes

# %% [markdown]
# ## ENERGYSTARScore

# %%
# Il n'y a pas de valeurs aberrante à traiter : aucune valeur en dessous de 0 ou au dessus de 100.
B_E_B['ENERGYSTARScore'].describe()
# Out:
# count    1088.000000
# mean       65.401654
# std        28.520421
# min         1.000000
# 25%        48.000000
# 50%        73.000000
# 75%        89.000000
# max       100.000000
# Name: ENERGYSTARScore, dtype: float64

# %% [markdown]
# ## DataYear

# %%
# Il n'y a pas de valeurs aberrante à traiter ; toutes les données sont datées de 2016
B_E_B["DataYear"].agg([min, max])
# Out:
# min    2016
# max    2016
# Name: DataYear, dtype: int64

# %% [markdown]
# ## Localisation et attributs

# %%
# Il n'y a pas de valeurs aberrante à traiter : tous les bâtiments sont de Seattle
B_E_B["City"].unique()
# Out:
# array(['Seattle'], dtype=object)

# %%
# iDEM
B_E_B["State"].unique()
# Out:
# array(['WA'], dtype=object)

# %%
B_E_B["NumberofFloors"].unique()
# Out:
# array([12, 11, 41, 10, 18,  2,  8, 15, 25,  9, 33,  6, 28,  5, 19,  7,  1,
#         3,  4, 24, 20, 34,  0, 16, 23, 17, 36, 22, 47, 29, 14, 49, 37, 42,
#        63, 13, 21, 55, 46, 30, 56, 76, 27, 99, 39], dtype=int64)

# %%
# Il y a des valeurs aberrantes, et le tri ne fonctionne pas. 
Floors = B_E_B["NumberofFloors"].value_counts(sort=True, normalize=False)
print(Floors)
# Out:
# 1     449
# 2     389
# 3     269
# 4     144
# 5     102
# 6      83
# 7      33
# 8      21
# 10     18
# 11     18
# 0      16
# 14      9
# 12      9
# 9       8
# 13      7
# 15      6
# 42      5
# 19      5
# 17      4
# 16      3
# 21      3
# 22      3
# 23      3
# 29      3
# 18      3
# 20      3
# 24      3
# 25      3
# 33      3
# 36      2
# 34      2
# 41      2
# 46      1
# 99      1
# 27      1
# 76      1
# 56      1
# 30      1
# 28      1
# 55      1
# 63      1
# 37      1
# 49      1
# 47      1
# 39      1
# Name: NumberofFloors, dtype: int64

# %%
# Cette église de 2 étages en a 99?
# https://www.google.com/search?q=seattle+chinese+baptist+church&rlz=1C1CHBF_frFR849FR849&sxsrf=AJOqlzXFXHN3Ztj7mlxiuCQgT0o7l1lcdA:1673278342479&source=lnms&tbm=isch&sa=X&ved=2ahUKEwivzdrJ57r8AhU0VaQEHSFPAdUQ_AUoA3oECAEQBQ&biw=1746&bih=786&dpr=1.1#imgrc=Af7ZJb7ko03EcM
B_E_B.loc[B_E_B["NumberofFloors"] == 99]
# Out:
#       OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 1359          21611      2016  NonResidential    Worship Facility
#
#                         PropertyName                   Address     City State  \
# 1359  Seattle Chinese Baptist Church  5801 Beacon Avenue South  Seattle    WA
#
#       ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# 1359  98108.0                    2124049098                    2
#
#           Neighborhood  Latitude  Longitude  YearBuilt  NumberofBuildings  \
# 1359  GREATER DUWAMISH  47.55072 -122.30265       1977                1.0
#
#       NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 1359              99             21948                   0
#
#       PropertyGFABuilding(s) ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 1359                   21948          Worship Facility       Worship Facility
#
#       LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# ...

# %% [markdown]
# # 3ème Nettoyage : Suppression des colonnes inutiles

# %% [markdown]
# ## Suppression des colonnes ayant la quasi totalité de leurs données manquantes : Comments & Outlier

# %%
# Comments : la variable devait sans doute servir de base pour indiquer un commentaire, 
# mais cela a dû se réléver inutiles au moment de la création de la database en pratique.
# Nous décidons donc de la supprimer.

# %%
# Objet : FLOAT, et non string, nous décidons de regarder les valeurs complétés pour être sûr. 
B_E_B['Comments'].dtype
# Out:
# dtype('float64')

# %%
B_E_B['Comments'].shape
# Out:
# (1644,)

# %%
# Aucune données remplies. 
B_E_B['Comments'].isna().sum()
# Out:
# 1644

# %%
# Suppression de la colonne Comments
del B_E_B['Comments']

# %%
# Outlier : la variable devait sans doute servir pour identifier des outliers
# Les données différencient entre haut et bas outlier ; mais la quasitotalité des données sont manquantes
# Nous décidons donc de la supprimer.

# %%
# Pandas Objet ; équivalent string en Python
B_E_B['Outlier'].dtype
# Out:
# dtype('O')

# %%
# Les données différencient entre haut et bas outlier.
notnull_rows = B_E_B.loc[B_E_B['Outlier'].notnull()]
print(notnull_rows)
# Out:
#       OSEBuildingID  DataYear        BuildingType  \
# 226             350      2016      NonResidential
# 384             539      2016      NonResidential
# 448             608      2016      NonResidential
# 517             704      2016      NonResidential
# 839           19967      2016   SPS-District K-12
# 1045          20617      2016      NonResidential
# 1229          21315      2016      NonResidential
# 1295          21474      2016      NonResidential
# 1611          22830      2016      NonResidential
# 1945          23912      2016      NonResidential
# 2129          24547      2016      NonResidential
# 2189          24717      2016      NonResidential
# 2216          24825      2016      NonResidential
# 2410          25553      2016      NonResidential
# 2450          25674      2016      NonResidential
# 2801          27007      2016      NonResidential
# 3152          43948      2016  Nonresidential COS
#
# ...

# %%
B_E_B.drop(columns=['Outlier'], inplace = True)
B_E_B.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# ...

# %% [markdown]
# ## Suppression des colonnes redondantes : WN
# Certaines variables sont les mêmes mais normalisées par la météo :
# Ce sont les variables qui finissent par le tag WN, qui signifie Weather Normalised
# Plus d'infos / à l'Energie Score : https://www.energystar.gov/sites/default/files/tools/Climate_and_Weather_2020_508.pdf
# Pour l'énergie score, il nous faudrait à la fois la météo, MAIS AUSSI le climat.
# Etant donné que ces données ne sont pas présente dans le df, nous préférons utiliser les variables de base.

# %%
B_E_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1644 entries, 0 to 3359
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    1644 non-null   int64
#  1   DataYear                         1644 non-null   int64
#  2   BuildingType                     1644 non-null   object
#  3   PrimaryPropertyType              1644 non-null   object
#  4   PropertyName                     1644 non-null   object
#  5   Address                          1644 non-null   object
#  6   City                             1644 non-null   object
#  7   State                            1644 non-null   object
#  8   ZipCode                          1644 non-null   float64
#  9   TaxParcelIdentificationNumber    1644 non-null   object
#  10  CouncilDistrictCode              1644 non-null   int64
#  11  Neighborhood                     1644 non-null   object
# ...

# %%
B_E_B.drop(columns=['SiteEUIWN(kBtu/sf)','SourceEUIWN(kBtu/sf)','SiteEnergyUseWN(kBtu)'], inplace = True)
B_E_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1644 entries, 0 to 3359
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    1644 non-null   int64
#  1   DataYear                         1644 non-null   int64
#  2   BuildingType                     1644 non-null   object
#  3   PrimaryPropertyType              1644 non-null   object
#  4   PropertyName                     1644 non-null   object
#  5   Address                          1644 non-null   object
#  6   City                             1644 non-null   object
#  7   State                            1644 non-null   object
#  8   ZipCode                          1644 non-null   float64
#  9   TaxParcelIdentificationNumber    1644 non-null   object
#  10  CouncilDistrictCode              1644 non-null   int64
#  11  Neighborhood                     1644 non-null   object
# ...

# %% [markdown]
# # Complétion des variables utiles

# %% [markdown]
# ## Energy Star Score

# %%
B_E_B['ENERGYSTARScore'].shape
# Out:
# (1644,)

# %%
B_E_B['ENERGYSTARScore'].isna().sum()
# Out:
# 556

# %%
msno.matrix(B_E_B.sample(50))
# Out:
# <AxesSubplot:>

# %%
# Complétion des valeurs manquantes? II, KNN?, simple à la moyenne?

# %% [markdown]
# # Modification/optimisation des variables utiles

# %% [markdown]
# ## YearsENERGYSTARCertified
# Ici, les valeurs nan représentes les batiments non certifiés; on peux éventuellement les remplacer par 0.
# Complément d'information sur la certification : https://www.energystar.gov/buildings/benchmark/analyze_benchmarking_results

# %%
B_E_B['YearsENERGYSTARCertified'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: YearsENERGYSTARCertified, dtype: object

# %%
B_E_B['YearsENERGYSTARCertified'].unique()
# Out:
# array([nan, '2016', '2014', '2012', '20172015',
#        '2017201620152014201320122011201020092008', '201020092007',
#        '201720102007', '20162015', '20152014201220112009', '201220092008',
#        '201620152014201320112010200920072000', '201620092008',
#        '201620142012', '20162015201420122008',
#        '2016201520142013201220112010200920082007200620052004',
#        '201520142013', '2014201320112010200920082007', '2016201520142013',
#        '2017201620152014201320112008', '201720162015201420132008',
#        '20162015201320122010', '2015201320122010', '20162011201020092008',
#        '2007', '2010', '20172016201520092008', '2017201320092008', '2015',
#        '2017', '2017201120102007', '201720162014201320122011201020092007',
#        '201720152014201220102008', '20092005', '2017201520142013',
#        '201620152012', '2012201020072006', '20112009', '2009',
#        '201620152014201320092008', '201620152014201320112009',
# ...

# %%
B_E_B['YearsENERGYSTARCertified'].shape
# Out:
# (1644,)

# %%
B_E_B['YearsENERGYSTARCertified'].isna().sum()
# Out:
# 1546

# %%
B_E_B['YearsENERGYSTARCertified'].fillna(0, inplace=True)

# %%
B_E_B['YearsENERGYSTARCertified'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: YearsENERGYSTARCertified, dtype: object

# %%
msno.matrix(B_E_B.sample(100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analyse univariée

# %% [markdown]
# ## OSEBuildingID

# %%
ana_uni_qtv_er(B_E_B, 'OSEBuildingID')
# Out:
# Il y a 1644.0 entrées.
# Il y a 0 valeurs manquantes
# La valeur min. est de 1.00.
# La valeur max. est de 50101.00.
# La moyenne est de 16024.47.
# L'étendue est de 50100.00.
# Le premier quartile se situe à 578.75.
# La médiane se situe à 21123.50.
# Le troisième quartile se situe à 24560.75.
# L'écart interquartile est de 23982.00.
# L'écart type est de 13496.43.

# %% [markdown]
# ## DataYear

# %%
ana_uni_qtv_er(B_E_B, 'DataYear')
# Out:
# Il y a 1644.0 entrées.
# Il y a 0 valeurs manquantes
# La valeur min. est de 2016.00.
# La valeur max. est de 2016.00.
# La moyenne est de 2016.00.
# L'étendue est de 0.00.
# Le premier quartile se situe à 2016.00.
# La médiane se situe à 2016.00.
# Le troisième quartile se situe à 2016.00.
# L'écart interquartile est de 0.00.
# L'écart type est de 0.00.

# %% [markdown]
# ## BuildingType

# %%
ana_uni_nom(B_E_B, 'BuildingType')
# Out:
# Il y a 1644 entrées.
# Il y a 0 valeurs manquantes
# Il y a 5 valeurs uniques.
# Le mode est de 1452.
# La valeur du mode correspond à NonResidential.

# %%
B_E_BBT_pie = B_E_B["BuildingType"].value_counts(sort=True, normalize=True).reset_index()
B_E_BBT_pie
# Out:
#                 index  BuildingType
# 0      NonResidential      0.883212
# 1   SPS-District K-12      0.059611
# 2  Nonresidential COS      0.041971
# 3              Campus      0.014599
# 4   Nonresidential WA      0.000608

# %%
#Représentation graphique 

fig, ax = plt.subplots(figsize=(8,8))
plt.pie(B_E_BBT_pie["BuildingType"], labels = B_E_BBT_pie["index"], autopct='%1.1f%%',  shadow = True)
plt.title('Types de bâtiment')
plt.legend(bbox_to_anchor=(0.7, 0, 1, 0.9))
plt.show()

# %% [markdown]
# ## PrimaryPropertyType

# %%
ana_uni_nom(B_E_B, 'PrimaryPropertyType')
# Out:
# Il y a 1644 entrées.
# Il y a 0 valeurs manquantes
# Il y a 21 valeurs uniques.
# Le mode est de 290.
# La valeur du mode correspond à Small- and Mid-Sized Office.

# %%
B_E_B_PPT = B_E_B["PrimaryPropertyType"].value_counts(sort=True, normalize=False).reset_index()
B_E_B_PPT
# Out:
#                           index  PrimaryPropertyType
# 0   Small- and Mid-Sized Office                  290
# 1                         Other                  240
# 2                     Warehouse                  187
# 3                  Large Office                  172
# 4                   K-12 School                  139
# 5            Mixed Use Property                  109
# 6                  Retail Store                   91
# 7                         Hotel                   75
# 8              Worship Facility                   71
# 9           Distribution Center                   53
# 10  Supermarket / Grocery Store                   40
# 11               Medical Office                   39
# 12        Self-Storage Facility                   27
# 13                   University                   24
# 14               Residence Hall                   21
# 15        Senior Care Community                   20
# 16       Refrigerated Warehouse                   12
# ...

# %%
fig = plt.figure(figsize=(8,8)) 
Bplot = sns.countplot(data=B_E_B["PrimaryPropertyType"], y = B_E_B["PrimaryPropertyType"].index)
Bplot.set_title("Type des bâtiments non-résidentiels", pad = 15)
plt.xticks(rotation=90,fontsize=11,fontweight='bold')
plt.show()

# %% [markdown]
# ## YearBuilt

# %%
ana_uni_qtv_er(B_E_B, 'YearBuilt')
# Out:
# Il y a 1644.0 entrées.
# Il y a 0 valeurs manquantes
# La valeur min. est de 1900.00.
# La valeur max. est de 2015.00.
# La moyenne est de 1961.87.
# L'étendue est de 115.00.
# Le premier quartile se situe à 1930.00.
# La médiane se situe à 1965.00.
# Le troisième quartile se situe à 1989.00.
# L'écart interquartile est de 59.00.
# L'écart type est de 32.71.

# %%
plot_bins_distribution(B_E_B, 'YearBuilt', 25, "Distribution des années de construction en fonction des bâtiments", "Années", "Nbs de Bâtiments")

# %% [markdown]
# ## Nombres de bâtiments

# %%
ana_uni_qtv_er(B_E_B, 'NumberofBuildings')
# Out:
# Il y a 1644.0 entrées.
# Il y a 0 valeurs manquantes
# La valeur min. est de 0.00.
# La valeur max. est de 111.00.
# La moyenne est de 1.17.
# L'étendue est de 111.00.
# Le premier quartile se situe à 1.00.
# La médiane se situe à 1.00.
# Le troisième quartile se situe à 1.00.
# L'écart interquartile est de 0.00.
# L'écart type est de 2.95.

# %%
plot_bins_distribution(B_E_B, 'NumberofBuildings', 4, "Distribution du nombres de batiments par lot en fonction de leurs nombres", "Lot de Bâtiments", "Nbs de Bâtiments")

# %% [markdown]
# ## Nombres d'étages

# %%
ana_uni_qtv_er(B_E_B, 'NumberofFloors')
# Out:
# Il y a 1644.0 entrées.
# Il y a 0 valeurs manquantes
# La valeur min. est de 0.00.
# La valeur max. est de 99.00.
# La moyenne est de 4.15.
# L'étendue est de 99.00.
# Le premier quartile se situe à 1.00.
# La médiane se situe à 2.00.
# Le troisième quartile se situe à 4.00.
# L'écart interquartile est de 3.00.
# L'écart type est de 6.60.

# %%
plot_bins_distribution(B_E_B, 'NumberofFloors', 5, "Distribution des étages des batiments en fonction de leurs nombres", "Etages", "Nbs de Bâtiments")

# %%
B_E_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1644 entries, 0 to 3359
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    1644 non-null   int64
#  1   DataYear                         1644 non-null   int64
#  2   BuildingType                     1644 non-null   object
#  3   PrimaryPropertyType              1644 non-null   object
#  4   PropertyName                     1644 non-null   object
#  5   Address                          1644 non-null   object
#  6   City                             1644 non-null   object
#  7   State                            1644 non-null   object
#  8   ZipCode                          1644 non-null   float64
#  9   TaxParcelIdentificationNumber    1644 non-null   object
#  10  CouncilDistrictCode              1644 non-null   int64
#  11  Neighborhood                     1644 non-null   object
# ...

# %% [markdown]
# # Analyse multivariée

# %% [markdown]
# ## Heatmap des corrélations (Pearson)

# %%
# Drop des colonnes inutiles : année du dataset qui est 2016, et code associé à chaque bâtiment.
B_E_B_Heatmap = B_E_B.drop(columns=['DataYear','OSEBuildingID'])

# %%
# Création de la matrice de masque
mask = np.zeros_like(B_E_B_Heatmap.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


# Affichage de la heatmap avec le masque
plt.figure(figsize=(15,15))
sns.heatmap(B_E_B_Heatmap.corr(method = "pearson"), annot=True, fmt=".1f", annot_kws={'size':11}, mask=mask, center=0, cmap="coolwarm").set(title='Heatmap des corrélations de Bravais-Pearson')
# Out:
# C:\Users\Trunky\AppData\Local\Temp\ipykernel_8292\3156218835.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(B_E_B_Heatmap.corr(), dtype=np.bool)
# [Text(0.5, 1.0, 'Heatmap des corrélations de Bravais-Pearson')]

# %% [markdown]
# ## Tableau des corrélations (Pearson)

# %%
corr_HM = B_E_B_Heatmap.corr()

# Valeurs de corrélation dans un tableau à deux dimensions
corr_HM_table = corr_HM.style.background_gradient(cmap='coolwarm')
corr_HM_table
# Out:
# <style type="text/css">
# #T_88f2c_row0_col0, #T_88f2c_row1_col1, #T_88f2c_row2_col2, #T_88f2c_row3_col3, #T_88f2c_row4_col4, #T_88f2c_row5_col5, #T_88f2c_row6_col6, #T_88f2c_row7_col7, #T_88f2c_row8_col8, #T_88f2c_row9_col9, #T_88f2c_row10_col10, #T_88f2c_row11_col11, #T_88f2c_row12_col12, #T_88f2c_row13_col13, #T_88f2c_row14_col14, #T_88f2c_row15_col15, #T_88f2c_row16_col16, #T_88f2c_row17_col17, #T_88f2c_row18_col18, #T_88f2c_row18_col19, #T_88f2c_row19_col18, #T_88f2c_row19_col19, #T_88f2c_row20_col20, #T_88f2c_row20_col21, #T_88f2c_row21_col20, #T_88f2c_row21_col21, #T_88f2c_row22_col22, #T_88f2c_row23_col23, #T_88f2c_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_88f2c_row0_col1, #T_88f2c_row1_col10, #T_88f2c_row3_col16, #T_88f2c_row4_col10, #T_88f2c_row11_col2, #T_88f2c_row14_col0, #T_88f2c_row24_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# ...
